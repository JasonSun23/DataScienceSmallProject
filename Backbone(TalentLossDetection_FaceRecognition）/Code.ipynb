# %% [markdown]
# # Case Study 4 :  Data Science Shark Tank:  Pitch Your Ideas

# %% [markdown]
# Group 10 members:
# Jiexuan Sun, Zhaoning Su, Congyang Wang, Chao Xu

# %% [markdown]
# After the previous 3 case studies,  your team has now equipped with all the three powerful skills of data science: Hacking skill, Business skill and Math skill. In this project, your team is going to make use of these skills to come up with an idea of a new business/startup based upon data science technology. Your goal is to design a better service/solution on any data you like, develop a prototype/demo and prepare a pitch for your idea.
# * Your team needs to decide which business problem is important for the market you are joining in (for example, social media market, housing market, search market, etc.).
# * Then design a data science approach to improve one of the current services or design a new service on any data that you choose.
# * The solution should include all the three components of data science: 1) the business part to analyze the potential impact of your new/improved service, why the idea can make money, how much are you evaluating the company; How are you planing to persuade the sharks to invest in your business; 2) the mathematical part to formulate the problem and develop math solution; 3) the programming part to collect the data, implement the math solution, and develop the prototype/demo.

# %% [markdown]
# ### Problem 1: the Business Part (20 points)
#  As a group, learn about the data science related business and research about the current markets: such as search, social media, advertisement, recommendation and so on.
# Pick one of the markets for further consideration, and design a new service  which you believe to be important in the market.
# Define precisely in the report and briefly in the cells below, what is the business problem that your team wants to solve.
# Why the problem is important to solve?
# Why you believe you could make a big difference with data science technology.
# How are you planing to persuade the investors to buy in your idea.

# %% [markdown]
# **Please describe here *briefly*  (please edit this cell)**
#
# ***1) Your business problem to solve:***
#
# We would like to build a human resource management system to prevent the loss of key talents.
#
#
# ***2) Why the problem is important to solve?***
#
# Needless to say, employees are the core and soul of the enterprise. They are the engine of enterprise operating and growth, especially for those key talents. The cost of talent loss is very high for each company. So, detecting potential leaving employee is certainly needed for each company. Then, Company have the chance to take the necessary measures to prevent this 'tragedy' happening.
#
# ***3) What is your idea to solve the problem?***
#
# The human resource management system we designed have three parts.
#
# a) The 'Gamified' human resource management part.
#
# We 'gamify' each employees' career. For example, there are gamification-career record system and many game ‘indicators’ such as 'level', 'experience' and etc. On the one side, this structure hope to relieve employees from boring works. On the other side, we would like to build a sense of belonging for each emplyees. This could solve the talent loss problem from root. This structure is achieved through database design. Because it is not covered in this course, we won't mentioned any details in the following.
#
# b) The Face and smile recognition part.
#
# The second part of the system is our face recognition technology for identity verification in access system. It will not only recognize our employees' face but also detect whether they smile or not. By contrasting whether they smile or not before and after one day's work, we could predict whether they satisfy with today's work by their smile. After collecting enough data, we could compute each employee's 'satisfaction level'. This part use the machine learning knowledge. We would introduce the details in the following.
#
# c) The Talent loss detecing part.
#
# We could collect the data of employee's satisfaction level by using face and smile recognition part. By combining this important data with other human resources information, we could use them to detect the potential leaving employee. This could solve the talent loss problem from the 'surface'. But, it is quite useful and will get effect instantly.   We would introduce the details in the following.
#
# ***4) What differences you could make with your data science approach?***
#
# The data science approach couold find the potential leaving employee accurately and precisely. Compared with traditional human resource management approach, it doesn't need to prevent talent loss from the level of all the staffs. The data science help you find the target empoyee quickly. It would save lots of resources.
#
# ***5) Why do you believe the idea deserves the investment of the "sharks"?***
#
# First, the system's predicting accuracy of potential leaving employee is 0.98. Which means almost all the employee who want to quit will be detected, which means the model is robust and stable. So, the system is reliable.
#
# The system is easy to implement and inexpensive. Compared with the cost of key talents loss, the cost of this system is rather minimal. Investing in this system is a wise choice. So, the system has low-cost.
#
# Key talents are so important for each company. The cost of Key talents loss is quite high. A system which could prevent key talent loss means save/earn resources for company. So, the system has high profit-margin
#
# All in all, the potential value behind it is huge. So, this system deserves the investment.

# %% [markdown]
# ### Problem 2: The Math Part (20 points)

# %% [markdown]
# Define the business problem as a math problem and design a math solution to the problem.

# %% [markdown]
# #### 1. The face and smile recognition part.
#
# ***1) Problem formulation and its 'solution' in Math:***
#
# In this modular we do two things: First, we use PCA and SVM to do a face recognition which can be used for judging whether a person is a staff of the company. Second we use K-fold cross-validation and SVM to do a supervised learning to judge a person is smiling or not.
#
#
# The PCA(Principal component analysis) method is a statistical procedure that uses an orthogonal transformation to convert a set of observations of possibly correlated variables into a set of values of linearly uncorrelated variables called principal components:
#
# <img src='PCA1.png'>
#
# The K-fold cross-validation is a model validation technique for assessing how the results of a statistical analysis will generalize to an independent data set. With k-fold Cross Validation, we divide the data set into K different parts. Then remove the first part, fit the model on the remaining K-1 parts, and see how good the predictions are on the left out part and repeat this K different times taking out a different part each time.By averaging the K different MSE’s we get an estimated validation (test) error rate for new observations.
#
#
# The SVM(Support vector machines) method is a kind of supervised learning model with associated learning algorithms that analyze data used for classification and regression analysis. In SVM method we use lagrange duality and kernel function to get the maximum value.
#
# <img src='SVM1.png'>

# %% [markdown]
# #### 2.The talent loss detecing part.
# ***1) Problem formulation in Math:***
#
# After trying multiple classifier, we finally decide to use the Logistic Regression. The logistic Regression would give us each employee's leaving probability. We set 0.5 as our threshold. Then, we could use this model to predict who might want to quit.
#
# <img src='Fomuler_LogisticRegression.png'>
#
# ***2) Math Solution:***
#
# We use the Likelihood function to 'solve' the Logistic Regression.
#
# <img src='ANS0_LogisticRegression.png'>
# <img src='ANS1_LogisticRegression.png'>
# <img src='ANS2_LogisticRegression.png'>
#
# ***3) Implementation of the Solution:***
#
# We first split our data into testing and training dataset. Then, We use sklearn's 'linear_model' module fit our training dataset into LogistRegression model. Finally, we use the testing dataset to test the model performance.

# %% [markdown]
# ### Problem 3: The Hacking Part  (20 points)

# %% [markdown]
# * Data Collection
# * Implement a small Demo/Prototype/experiment result figures for the "product" of your data science company. You could use this demo during the Pitch

# %% [markdown]
# #### 1. The face and smile recognition part.

# %%
# Use PCA and SVM to do a face recognition
# By doing this we can recognize whether a man is a staff of company
# Refer to http://scikit-learn.org/stable/auto_examples/applications/face_recognition.html

from __future__ import print_function

from time import time
import logging
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import fetch_lfw_people
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn.svm import SVC

# Display progress logs on stdout
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(message)s')
lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape

# for machine learning we use the 2 data directly (as relative pixel
# positions info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# the label to predict is the id of the person
y = lfw_people.target
target_names = lfw_people.target_names
n_classes = target_names.shape[0]

print("Total dataset size:")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features)
print("n_classes: %d" % n_classes)

# split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Use PCA to find the eigenimage and do the cluster
n_components = 150
print("Extracting the top %d eigenfaces from %d faces" % (n_components, X_train.shape[0]))
t0 = time()
pca = PCA(n_components=n_components, svd_solver='randomized',whiten=True).fit(X_train)
print("done in %0.3fs" % (time() - t0))

# Get the eigenfaces
eigenfaces = pca.components_.reshape((n_components, h, w))
print("Projecting the input data on the eigenfaces orthonormal basis")
t0 = time()
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print("done in %0.3fs" % (time() - t0))

print("Fitting the classifier to the training set")
t0 = time()
param_grid = {'C': [1e3, 5e3, 1e4, 5e4, 1e5],
              'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1], }
clf = GridSearchCV(SVC(kernel='rbf', class_weight='balanced'), param_grid)
clf = clf.fit(X_train_pca, y_train)
print("done in %0.3fs" % (time() - t0))
print("Best estimator found by grid search:")
print(clf.best_estimator_)

print("Predicting people's names on the test set")
t0 = time()
y_pred = clf.predict(X_test_pca)
print("done in %0.3fs" % (time() - t0))

print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test, y_pred, labels=range(n_classes)))

def plot_gallery(images, titles, h, w, n_row=3, n_col=4):
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

# plot the result of the prediction on a portion of the test set
def title(y_pred, y_test, target_names, i):
    pred_name = target_names[y_pred[i]].rsplit(' ', 1)[-1]
    true_name = target_names[y_test[i]].rsplit(' ', 1)[-1]
    return 'predicted: %s\ntrue:      %s' % (pred_name, true_name)

prediction_titles = [title(y_pred, y_test, target_names, i)
                     
for i in range(y_pred.shape[0])]
plot_gallery(X_test, prediction_titles, h, w)

# plot the gallery of the most significative eigenfaces

eigenface_titles = ["eigenface %d" % i for i in range(eigenfaces.shape[0])]
plot_gallery(eigenfaces, eigenface_titles, h, w)

plt.show()
# Out:
# Total dataset size:
# n_samples: 556
# n_features: 1850
# n_classes: 2
# Extracting the top 150 eigenfaces from 417 faces
# done in 0.514s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.032s
# Fitting the classifier to the training set
# done in 6.784s
# Best estimator found by grid search:
# SVC(C=1000.0, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Predicting people's names on the test set
# done in 0.008s
#                    precision    recall  f1-score   support
#
#     George W Bush       0.98      0.97      0.98       113
# Gerhard Schroeder       0.89      0.92      0.91        26
#
#       avg / total       0.96      0.96      0.96       139
#
# [[110   3]
#  [  2  24]]

# %%
# We first pick the face from photo by OpenCV3
# For classifying whether a face is a smiling one, we transform the result image matching our training data Olivetti dataset faces which is an example data from scikit-learn.org
# Here we install the wheel.xml file for being able to use package suitble for lower version of python
# refer a python2 version code: "http://flothesof.github.io/smile-recognition.html"

import numpy as np
import cv2
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from scipy.ndimage import zoom

input_face = cv2.imread('D:\\16fall\\DS501\\case4\\randy1.png')
cascPath = "D:\\16fall\\DS501\\case4\\haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascPath)
gray = cv2.cvtColor(input_face, cv2.COLOR_BGR2GRAY)
detected_faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=6,
        minSize=(100, 100),
        flags=cv2.CASCADE_SCALE_IMAGE
    )

# show the face we'd like to recognize
detected_faces
ax = plt.gca()
ax.imshow(gray, cmap='gray')
for (x, y, w, h) in detected_faces:
    ax.add_artist(Rectangle((x, y), w, h, fill=False, lw=5, color='blue'))
original_extracted_face = gray[y:y+h, x:x+w]
horizontal_offset = 0.15 * w
vertical_offset = 0.2 * h
extracted_face = gray[y+vertical_offset:y+h, 
                      x+horizontal_offset:x-horizontal_offset+w]
# Out:
# D:\Users\jinliu\Anaconda3\lib\site-packages\ipykernel\__main__.py:34: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#change format of the face image for matching Olivetti dataset faces
from scipy.ndimage import zoom
classify_face = zoom(extracted_face,(64./extracted_face.shape[0], 
                                        64./extracted_face.shape[1]))
classify_face = classify_face.astype(float32)
classify_face/=float(classify_face.max())
display_face(classify_face[:, :])

# %%
# A simple smiling recognition training GUE
# %matplotlib inline
from pylab import *
from sklearn import datasets
import json

#get the Olivetti faces dataset from scikit-learn.org
faces = datasets.fetch_olivetti_faces()
for i in range(10):
    face = faces.images[i]
    subplot(1, 10, i + 1)
    imshow(face.reshape((64, 64)), cmap='gray')
    axis('off')

#Train the dataset whether it is a smiling one
#First we use a button GUI to label the images
#Here we only label 50 of the images for an example
from ipywidgets import interact, Button
from IPython.display import display, clear_output

class Trainer:
    def __init__(self):
        self.results = {}
        self.imgs = faces.images
        self.index = 0 # to order the images
        
    def increment_face(self):
        if self.index+1>=50:
            return(self.index)
        else:
            while str(self.index) in self.results:
                print(self.index)
                self.index+=1
            return(self.index)
    
    def record_result(self, smile=True):
        self.results[str(self.index)]= smile
        
trainer = Trainer()
button_smile = Button(description='smile')
button_no_smile = Button(description='sad')

def display_face(face):
    clear_output()
    imshow(face, cmap='gray')
    axis('off')

def update_smile(b):  # set smile
    trainer.record_result(smile=True)
    trainer.increment_face()
    display_face(trainer.imgs[trainer.index])

def update_no_smile(b):  # set no smile
    trainer.record_result(smile=False)
    trainer.increment_face()
    display_face(trainer.imgs[trainer.index])

button_no_smile.on_click(update_no_smile)
button_smile.on_click(update_smile)

display(button_smile)
display(button_no_smile)
display_face(trainer.imgs[trainer.index])

# %%
# Save the classify result in 'sr_results.xml'
with open('sr_results.xml', 'w') as f:
    json.dump(trainer.results, f)

results = json.load(open('sr_results.xml'))
trainer.results = results

# Show the results
print(results)

# Show smiling faces
smiling_faces = [int(i) for i in results if results[i] == True]
fig = plt.figure(figsize=(12, 12))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
print("smile faces:")
for i in range(len(smiling_faces)):
    # plot the images in a size 20x20
    p = fig.add_subplot(20, 20, i + 1)
    p.imshow(faces.images[smiling_faces[i]], cmap=plt.cm.bone)
    p.axis('off')
# Out:
# {'37': False, '14': True, '2': False, '0': False, '26': True, '6': False, '40': True, '38': False, '4': False, '25': False, '11': False, '44': True, '29': True, '27': True, '10': False, '9': False, '28': True, '39': False, '49': True, '3': False, '17': True, '46': True, '15': True, '35': False, '43': True, '41': True, '21': True, '22': True, '33': False, '36': False, '12': False, '19': True, '7': False, '23': True, '34': False, '8': False, '32': False, '13': True, '47': True, '24': False, '1': False, '30': False, '31': False, '18': True, '20': True, '45': True, '16': True, '48': True, '42': True, '5': False}
# smile faces:

# %%
# Refer to http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
from sklearn.svm import SVC
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score, KFold
from scipy.stats import sem

# Use SVC do the training
svc_1 = SVC(kernel='linear')
classify_results = [i for i in trainer.results]
data = faces.data[classify_results,:]
data = data[0:50]

# Split the data 
target = [trainer.results[i] for i in trainer.results]
target = array(target).astype(int32)
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.25, random_state=0)

# Use the cross_validation method to improve the accurate of prediction
def evaluate_cross_validation(clf, X, y, K):
    cv = KFold(len(y), K, shuffle=True, random_state=0)
    scores = cross_val_score(clf, X, y, cv=cv)
    print (scores)
    print ("Mean score: {0:.3f} (+/-{1:.3f})".format(np.mean(scores), sem(scores)))

evaluate_cross_validation(svc_1, X_train, y_train, 5)
# Out:
# [ 0.625       1.          0.85714286  0.71428571  0.71428571]
# Mean score: 0.782 (+/-0.066)
# D:\Users\jinliu\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\Users\jinliu\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: VisibleDeprecationWarning: non integer (and non boolean) array-likes will not be accepted as indices in the future

# %%
#Predict the new photo whether is a smiling one

import numpy as np
import cv2
import matplotlib.pyplot as plt

svc_1.fit(X_train, y_train)
y_pred = svc_1.predict(X_test)

display_face(classify_face[:, :])
print("New Photo for prediction")

pred_result = svc_1.predict(classify_face.ravel())
if pred_result==1:
    new="yes"
else:
    new="no"
print("This person is smiling or not:",new)
# Out:
# New Photo for prediction
# This person is smiling or not: yes
# D:\Users\jinliu\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %% [markdown]
# #### 2. The talent loss detecing part.

# %%
import pandas
import matplotlib.pyplot as plt
import matplotlib.pylab as py
import numpy
# %matplotlib inline

#Load the data.
data = pandas.read_csv('HR_comma_sep.csv')
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
#Explore the original dataset.

#Calculate some basic statistics of the dataset.
statistics=data.describe(percentiles=None, include=None, exclude=None)
statistics
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
#Calculate the correlation of the dataset and visualize it.
correlation=data.corr(method='pearson', min_periods=1)
print(correlation)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlation, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,8,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_yticklabels(list(data.columns.values))
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
#Explore the dataset with only employee who leave the company.

#Create the dataset with only employee who leave the company.
data_left=data[(data.left==1)]
data_left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
#Draw histogram of different variables between full dataset and the dataset only including leaving employee
#Compare shape of the histgram beween these two dataset.
py.subplot(5, 2, 1)
plt.hist(data_left['satisfaction_level'], bins=10)
plt.title('Histogram of the satisfaction level with left employee', fontsize=9)
plt.xlabel('satisfaction level')
plt.ylabel('Frequency')
plt.grid(True)
py.subplot(5, 2, 2)
plt.hist(data['satisfaction_level'], bins=10)
plt.title('Histogram of the satisfaction level with all employee', fontsize=9)
plt.xlabel('satisfaction level')
plt.ylabel('Frequency')
plt.grid(True)

py.subplot(5, 2, 3)
plt.hist(data_left['last_evaluation'], bins=10)
plt.title('Histogram of the last evaluation with left employee', fontsize=9)
plt.xlabel('last_evaluation')
plt.ylabel('Frequency')
plt.grid(True)
py.subplot(5, 2, 4)
plt.hist(data['last_evaluation'], bins=10)
plt.title('Histogram of the last evaluation with all employee', fontsize=9)
plt.xlabel('last_evaluation')
plt.ylabel('Frequency')
plt.grid(True)

py.subplot(5, 2, 5)
plt.hist(data_left['average_montly_hours'], bins=10)
plt.title('Histogram of the average montly hours with left employee', fontsize=9)
plt.xlabel('average montly hours')
plt.ylabel('Frequency')
plt.grid(True)
py.subplot(5, 2, 6)
plt.hist(data['average_montly_hours'], bins=10)
plt.title('Histogram of the average montly hours with all employee', fontsize=9)
plt.xlabel('average montly hours')
plt.ylabel('Frequency')
plt.grid(True)
plt.subplots_adjust(bottom=0.1, right=3, top=5.0, left=0.1)

py.subplot(5, 2, 7)
plt.hist(data_left['time_spend_company'], bins=10)
plt.title('Histogram of the time_spend_company with left employee', fontsize=9)
plt.xlabel('time_spend_company')
plt.ylabel('Frequency')
plt.grid(True)
py.subplot(5, 2, 8)
plt.hist(data['time_spend_company'], bins=10)
plt.title('Histogram of the time_spend_company with all employee', fontsize=9)
plt.xlabel('time_spend_company')
plt.ylabel('Frequency')
plt.grid(True)
plt.subplots_adjust(bottom=0.1, right=3, top=6.0, left=0.1)

py.subplot(5, 2, 9)
plt.hist(data_left['number_project'], bins=10)
plt.title('Histogram of the number_project with left employee', fontsize=9)
plt.xlabel('number_project')
plt.ylabel('Frequency')
plt.grid(True)
py.subplot(5, 2, 10)
plt.hist(data['number_project'], bins=10)
plt.title('Histogram of the number_project with all employee', fontsize=9)
plt.xlabel('number_project')
plt.ylabel('Frequency')
plt.grid(True)
plt.subplots_adjust(bottom=0.1, right=3, top=6.0, left=0.1)

'''
py.subplot(5, 2, 7)
plt.hist(data_left['salary'], bins=10)
plt.title('Histogram of the salary with left employee', fontsize=9)
plt.xlabel('salary')
plt.ylabel('Frequency')
plt.grid(True)
py.subplot(5, 2, 8)
plt.hist(data['salary'], bins=10)
plt.title('Histogram of the salary with all employee', fontsize=9)
plt.xlabel('salary')
plt.ylabel('Frequency')
plt.grid(True)
plt.subplots_adjust(bottom=0.1, right=3, top=5.0, left=0.1)
'''
# Out:
# "\npy.subplot(5, 2, 7)\nplt.hist(data_left['salary'], bins=10)\nplt.title('Histogram of the salary with left employee', fontsize=9)\nplt.xlabel('salary')\nplt.ylabel('Frequency')\nplt.grid(True)\npy.subplot(5, 2, 8)\nplt.hist(data['salary'], bins=10)\nplt.title('Histogram of the salary with all employee', fontsize=9)\nplt.xlabel('salary')\nplt.ylabel('Frequency')\nplt.grid(True)\nplt.subplots_adjust(bottom=0.1, right=3, top=5.0, left=0.1)\n"

# %%
#Defind 'good' employee (key talent) and create the dataset with only "good" employee.
#Find the Number of employee who left the company, Number of "good" employee, Number of "good" employee left the company.

num_left=len(data_left)
print('Number of employee who left the company:')
print(num_left)

data_good=data[(data.last_evaluation >= 0.7) | (data.time_spend_company >= 4) | (data.number_project >= 5)]
num_good=len(data_good)
print('Number of "good" employee:')
print(num_good)

data_left_good=data_left[(data_left.last_evaluation >= 0.7) | (data_left.time_spend_company >= 4) | (data_left.number_project >= 5)]
num_data_good=len(data_left_good)
print('Number of "good" employee left the company:')
print(num_data_good)
# Out:
# Number of employee who left the company:
# 3571
# Number of "good" employee:
# 10394
# Number of "good" employee left the company:
# 2020

# %%
#Calculate the correlation of the dataset with only "good" employee and visualize it.

correlation=data_good.corr(method='pearson', min_periods=1)
print(correlation)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlation, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,8,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_yticklabels(list(data_good.columns.values))
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.042908       -0.378779
# last_evaluation                  0.042908         1.000000        0.005783
# number_project                  -0.378779         0.005783        1.000000
# average_montly_hours            -0.185775         0.192981        0.279795
# time_spend_company              -0.122484        -0.121681        0.058309
# Work_accident                    0.042612        -0.055484       -0.064771
# left                            -0.293666         0.284601        0.441011
# promotion_last_5years            0.024605        -0.040042       -0.038096
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.185775           -0.122484
# last_evaluation                    0.192981           -0.121681
# number_project                     0.279795            0.058309
# ...

# %%
#Calculate some basic statistics of the dataset with only "good" employee.

statistics_good=data_good.describe(percentiles=None, include=None, exclude=None)
statistics_good
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        10394.000000     10394.000000    10394.000000
# mean             0.622389         0.788323        4.209255
# std              0.266435         0.151613        1.165175
# min              0.090000         0.360000        2.000000
# 25%              0.500000         0.710000        3.000000
# 50%              0.680000         0.820000        4.000000
# 75%              0.830000         0.910000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          10394.000000        10394.000000   10394.000000  10394.000000
# mean             211.281701            3.837887       0.152011      0.194343
# std               48.798266            1.616743       0.359049      0.395713
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
#Use Decision Tree Classifier to detect the employee who wants to leave.
#Test the model and calculate its accuracy.

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree

x_train, x_test, y_train, y_test = train_test_split(data_good.drop('left', 1), data_good.left, test_size=0.25, random_state=None)

salary = {"low":0.0 ,"medium" :1.0,"high":2.0}
sales = {'accounting':0.0,'hr':1.0,'IT':2.0,'management':3.0,'marketing':4.0,'product_mng':5.0,'RandD':6.0,'sales':7.0,'support':8.0,'technical':9.0}

x_train['salary'] = x_train['salary'].apply(salary.get).astype(float)
x_train['sales'] = x_train['sales'].apply(sales.get).astype(float)
x_test['salary'] = x_test['salary'].apply(salary.get).astype(float)
x_test['sales'] = x_test['sales'].apply(sales.get).astype(float)

clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)
y_predicted = clf.predict(x_test)
print(metrics.classification_report(y_test, y_predicted,target_names=list(data_good.columns.values)))
cm = metrics.confusion_matrix(y_test, y_predicted)
print(cm)
import matplotlib.pyplot as plt
plt.matshow(cm)
plt.colorbar()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
#                        precision    recall  f1-score   support
#
#    satisfaction_level       0.99      0.98      0.98      2130
#       last_evaluation       0.90      0.96      0.93       469
#
#           avg / total       0.97      0.97      0.97      2599
#
# [[2080   50]
#  [  19  450]]

# %%
#Use Logistic Regression to detect the employee who wants to leave.
#Test the model and calculate its accuracy.

from sklearn import linear_model

x_train, x_test, y_train, y_test = train_test_split(data_good.drop('left', 1), data_good.left, test_size=0.25, random_state=None)

salary = {"low":0.0 ,"medium" :1.0,"high":2.0}
sales = {'accounting':0.0,'hr':1.0,'IT':2.0,'management':3.0,'marketing':4.0,'product_mng':5.0,'RandD':6.0,'sales':7.0,'support':8.0,'technical':9.0}

x_train['salary'] = x_train['salary'].apply(salary.get).astype(float)
x_train['sales'] = x_train['sales'].apply(sales.get).astype(float)
x_test['salary'] = x_test['salary'].apply(salary.get).astype(float)
x_test['sales'] = x_test['sales'].apply(sales.get).astype(float)

clf2 = linear_model.LogisticRegression()
clf2 = clf2.fit(x_train, y_train)
y_predicted = clf.predict(x_test)
print(y_predicted)
print(metrics.classification_report(y_test, y_predicted))
cm = metrics.confusion_matrix(y_test, y_predicted)
print(cm)
import matplotlib.pyplot as plt
plt.matshow(cm)
plt.colorbar()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [0 1 1 ..., 0 0 0]
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      2075
#           1       0.98      1.00      0.99       524
#
# avg / total       1.00      1.00      1.00      2599
#
# [[2065   10]
#  [   2  522]]

# %%
#Use LinearSVC to detect the employee who wants to leave.
#Test the model and calculate its accuracy.

from sklearn import svm

x_train, x_test, y_train, y_test = train_test_split(data_good.drop('left', 1), data_good.left, test_size=0.25, random_state=None)

salary = {"low":0.0 ,"medium" :1.0,"high":2.0}
sales = {'accounting':0.0,'hr':1.0,'IT':2.0,'management':3.0,'marketing':4.0,'product_mng':5.0,'RandD':6.0,'sales':7.0,'support':8.0,'technical':9.0}

x_train['salary'] = x_train['salary'].apply(salary.get).astype(float)
x_train['sales'] = x_train['sales'].apply(sales.get).astype(float)
x_test['salary'] = x_test['salary'].apply(salary.get).astype(float)
x_test['sales'] = x_test['sales'].apply(sales.get).astype(float)


clf3 = svm.LinearSVC()
clf3 = clf3.fit(x_train, y_train)                         

print(metrics.classification_report(y_test, y_predicted))
cm = metrics.confusion_matrix(y_test, y_predicted)
print(cm)
import matplotlib.pyplot as plt
plt.matshow(cm)
plt.colorbar()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.81      0.81      0.81      2098
#           1       0.20      0.20      0.20       501
#
# avg / total       0.69      0.69      0.69      2599
#
# [[1706  392]
#  [ 403   98]]

# %%
#Use KNN to detect the employee who wants to leave.
#Test the model and calculate its accuracy.

from sklearn import neighbors

x_train, x_test, y_train, y_test = train_test_split(data_good.drop('left', 1), data_good.left, test_size=0.25, random_state=None)

salary = {"low":0.0 ,"medium" :1.0,"high":2.0}
sales = {'accounting':0.0,'hr':1.0,'IT':2.0,'management':3.0,'marketing':4.0,'product_mng':5.0,'RandD':6.0,'sales':7.0,'support':8.0,'technical':9.0}

x_train['salary'] = x_train['salary'].apply(salary.get).astype(float)
x_train['sales'] = x_train['sales'].apply(sales.get).astype(float)
x_test['salary'] = x_test['salary'].apply(salary.get).astype(float)
x_test['sales'] = x_test['sales'].apply(sales.get).astype(float)

clf4 = neighbors.KNeighborsClassifier(n_neighbors=5)
clf4 = clf4.fit(x_train, y_train)

print(metrics.classification_report(y_test, y_predicted))
cm = metrics.confusion_matrix(y_test, y_predicted)
print(cm)
import matplotlib.pyplot as plt
plt.matshow(cm)
plt.colorbar()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.82      0.81      0.82      2125
#           1       0.19      0.19      0.19       474
#
# avg / total       0.70      0.70      0.70      2599
#
# [[1727  398]
#  [ 382   92]]

# %%
#Use Random Forest Classifier to detect the employee who wants to leave.
#Test the model and calculate its accuracy.

from sklearn import ensemble

x_train, x_test, y_train, y_test = train_test_split(data_good.drop('left', 1), data_good.left, test_size=0.25, random_state=None)

salary = {"low":0.0 ,"medium" :1.0,"high":2.0}
sales = {'accounting':0.0,'hr':1.0,'IT':2.0,'management':3.0,'marketing':4.0,'product_mng':5.0,'RandD':6.0,'sales':7.0,'support':8.0,'technical':9.0}

x_train['salary'] = x_train['salary'].apply(salary.get).astype(float)
x_train['sales'] = x_train['sales'].apply(sales.get).astype(float)
x_test['salary'] = x_test['salary'].apply(salary.get).astype(float)
x_test['sales'] = x_test['sales'].apply(sales.get).astype(float)

clf5 = ensemble.RandomForestClassifier()
clf5 = clf5.fit(x_train, y_train)

print(metrics.classification_report(y_test, y_predicted))
cm = metrics.confusion_matrix(y_test, y_predicted)
print(cm)
import matplotlib.pyplot as plt
plt.matshow(cm)
plt.colorbar()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
#              precision    recall  f1-score   support
#
#           0       0.80      0.80      0.80      2065
#           1       0.21      0.21      0.21       534
#
# avg / total       0.68      0.68      0.68      2599
#
# [[1647  418]
#  [ 420  114]]

# %% [markdown]
# ### We could collect the data of employee's satisfaction level by using face and smile recognition part. Obviously, people smile more often, they definitely more satisfied with their work.  By combining this important data with other human resources information, we could use them to detect the potential leaving employee.###

# %%
#We try to visualize the result and show the potential leaving employee for company.
#Based on the performance of these classifiers, we decide to use the logist regression to detect the employee who might quit.

from sklearn import linear_model

x_train, x_test, y_train, y_test = train_test_split(data_good.drop('left', 1), data_good.left, test_size=0.25, random_state=None)

salary = {"low":0.0 ,"medium" :1.0,"high":2.0}
sales = {'accounting':0.0,'hr':1.0,'IT':2.0,'management':3.0,'marketing':4.0,'product_mng':5.0,'RandD':6.0,'sales':7.0,'support':8.0,'technical':9.0}

x_train['salary'] = x_train['salary'].apply(salary.get).astype(float)
x_train['sales'] = x_train['sales'].apply(sales.get).astype(float)
x_test['salary'] = x_test['salary'].apply(salary.get).astype(float)
x_test['sales'] = x_test['sales'].apply(sales.get).astype(float)

clf_Logistic = linear_model.LogisticRegression()
clf_Logistic = clf_Logistic.fit(x_train, y_train)

xarr=[]

for i in range(len(x_test.index)):
    m=y_test.index[i]
    xarr.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],
                 clf_Logistic.predict_proba(x_test)[i][1]*data.iloc[m]['last_evaluation']])

y_predicted = clf.predict(x_test)
print(y_predicted)
print(metrics.classification_report(y_test, y_predicted))
cm = metrics.confusion_matrix(y_test, y_predicted)
print(cm)
import matplotlib.pyplot as plt
plt.matshow(cm)
plt.colorbar()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [0 1 0 ..., 0 0 0]
#              precision    recall  f1-score   support
#
#           0       1.00      0.99      1.00      2078
#           1       0.97      0.99      0.98       521
#
# avg / total       0.99      0.99      0.99      2599
#
# [[2064   14]
#  [   3  518]]

# %%
#We create the table about those employee who might leave and ordered them based on their 'priority'.
#Priority = ProbToLeave * Performance
df=pandas.DataFrame(xarr,columns=['id','probToLeave','performance','priority'])
#df.sort(columns='probToLeave')
am=df.sort_values(by='priority',ascending=False)
am
# Out:
#          id  probToLeave  performance  priority
# 1280   1648     0.970644         0.97  0.941525
# 989   12479     0.976362         0.96  0.937307
# 2017    809     0.965581         0.97  0.936614
# 396    1488     0.972664         0.96  0.933758
# 374   12160     0.976252         0.95  0.927440
# 864   12522     0.968830         0.95  0.920389
# 1473   1807     0.975763         0.94  0.917217
# 986   12550     0.946356         0.96  0.908501
# 8       311     0.950186         0.95  0.902676
# 867    1534     0.957798         0.94  0.900331
# 1602  14265     0.976940         0.92  0.898785
# 783   10294     0.926034         0.97  0.898253
# 33      820     0.965369         0.93  0.897794
# 2314  14810     0.974678         0.92  0.896704
# 1944    280     0.914521         0.98  0.896231
# 2215    952     0.953374         0.94  0.896172
# 160    1161     0.952493         0.94  0.895343
# 2382   1611     0.972563         0.92  0.894758
# 265    1037     0.922203         0.97  0.894537
# ...

# %%
#Then we plot the graph_1 as shown following. It plots each employee's leaving probability and performance evaluation.
#Please check the report for the analysis result detail.
xxx=[]
yyy=[]
sizea=len(am.index)
for i in range(sizea):
    xxx.append(am.iloc[i]['probToLeave'])
    yyy.append(am.iloc[i]['performance'])
    
plt.xlim(xmax=1,xmin=0) 
plt.ylim(ymax=1,ymin=0)
plt.xlabel('Probability of leaving')
plt.ylabel('Performance')
plt.plot(xxx,yyy,'ro') 

plt.show()

zzz=[]
z=[]
for i in range(sizea):
    zzz.append(xxx[i]*yyy[i])
    z.append(xxx[i]*yyy[i]*1000)

# %%
#Then we plot the graph_2 as shown following. It plots each employee's leaving probability and performance evaluation.
#Please check the report for the analysis result detail.
#Warning: To see the following plot, you might need to run the code.
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('JasonSun23', 'ze2jekbjzj')
data_1 = [
    {
        'x': xxx,
        'y': yyy,
        'text':zzz,
        'mode': 'markers',
        'marker': {
            'color': xxx,
            'size': z,
            'sizeref': 50,
            'showscale': True
        }
    }
]
py.iplot(data_1, filename='scatter-colorscale')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~JasonSun23/0 or inside your plot.ly account where it is named 'scatter-colorscale'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~JasonSun23/0.embed" height="525px" width="100%"></iframe>

# %%
#Then we plot the graph_3 as shown following. It plots top 10 leaving probability employee among different occupations,
#Please check the report for the analysis result detail.
occupy = ['accounting','hr','IT','management','marketing','product_mng','RandD','sales','support','technical']
print(occupy)
print()
xarr_0=[];xarr_1=[];xarr_2=[];xarr_3=[];xarr_4=[];xarr_5=[];xarr_6=[];xarr_7=[];xarr_8=[];xarr_9=[]
aa=[]
bb=[]
for i in range(len(x_test.index)):
    m=y_test.index[i]
    if data.iloc[m]['sales']=='accounting':
        xarr_0.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='hr':
        xarr_1.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='IT':
        xarr_2.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='management':
        xarr_3.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='marketing':
        xarr_4.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='product_mng':
        xarr_5.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='RandD':
        xarr_6.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='sales':
        xarr_7.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='support':
        xarr_8.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])
    if data.iloc[m]['sales']=='technical':
        xarr_9.append([m,clf_Logistic.predict_proba(x_test)[i][1],data.iloc[m]['last_evaluation'],data.iloc[m]['sales']])

xarr_0.sort(key=lambda x:x[1],reverse=True) 
xarr_1.sort(key=lambda x:x[1],reverse=True) 
xarr_2.sort(key=lambda x:x[1],reverse=True) 
xarr_3.sort(key=lambda x:x[1],reverse=True) 
xarr_4.sort(key=lambda x:x[1],reverse=True) 
xarr_5.sort(key=lambda x:x[1],reverse=True) 
xarr_6.sort(key=lambda x:x[1],reverse=True) 
xarr_7.sort(key=lambda x:x[1],reverse=True) 
xarr_8.sort(key=lambda x:x[1],reverse=True) 
xarr_9.sort(key=lambda x:x[1],reverse=True) 

tyx=[]
tyy=[]
for i in range(10):
    tyx.append(0)
    tyy.append(xarr_0[i][1])
    tyx.append(1)
    tyy.append(xarr_1[i][1])
    tyx.append(2)
    tyy.append(xarr_2[i][1])
    tyx.append(3)
    tyy.append(xarr_3[i][1])
    tyx.append(4)
    tyy.append(xarr_4[i][1])
    tyx.append(5)
    tyy.append(xarr_5[i][1])
    tyx.append(6)
    tyy.append(xarr_6[i][1])
    tyx.append(7)
    tyy.append(xarr_7[i][1])
    tyx.append(8)
    tyy.append(xarr_8[i][1])
    tyx.append(9)
    tyy.append(xarr_9[i][1])

plt.xlim(xmax=10,xmin=-1) 
plt.ylim(ymax=1,ymin=0.6)
plt.title('Top 10 leaving probability employee among different occupations')
plt.xlabel('accounting, hr, IT, management, marketing, product_mng, RandD, sales, support, technical')
plt.ylabel('Probility of leaving')
plt.plot(tyx,tyy,'ro',c='b')
plt.xticks(rotation=90)
plt.show()
# Out:
# ['accounting', 'hr', 'IT', 'management', 'marketing', 'product_mng', 'RandD', 'sales', 'support', 'technical']

# %% [markdown]
# *------------------------
#
# ### Problem 4: Prepare a 90 second Pitch and *present* it in the class (20 points)
#
# * Prepare the slide(s) for the Pitch (10 points)
# * Present it in the class (10 points).
#
# *Advice:  It should really only be one or two slides, but a really good one or two slides!  Also, it is ok to select one person on the team to give the 90 second pitch (though a very organized multi-person 90 second pitch can be very impressive!) *

# %% [markdown]
# # Report: communicate the results (20 points)
#
# (1) (5 points) What is your business proposition?
#
# (2) (5 points) Why this topic is interesting or important to you? (Motivations)
#
# (3) (5 points) How did you analyse the data?
#
# (4) (5 points) How does your analysis support your business proposition?
# (please include figures or tables in the report, but no source code)

# %% [markdown]
# # Slides (for 10 minutes of presentation) (20 points)
#
#
# 1. (5 points) Motivation about the data collection, why the topic is interesting to you.
#
# 2. (10 points) Communicating Results (figure/table)
#
# 3. (5 points) Story telling (How all the parts (data, analysis, result) fit together as a story?)

# %% [markdown]
# *-----------------
# # Done
#
# All set!
#
# ** What do you need to submit?**
#
# * **Notebook File**: Save this IPython notebook, and find the notebook file in your folder (for example, "filename.ipynb"). This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook. If you used "ipython notebook --pylab=inline" to open the notebook, all the figures and tables should have shown up in the notebook.
#
#
# * **PPT Slides**: **NOTE, for this Case Study you need to prepare two (2) PPT files!**  One for the 90 second Pitch and one for a normal 10 minute presentation.
#
# * ** Report**: please prepare a report (less than 10 pages) to report what you found in the data.
#
#      (please include figures or tables in the report, **but no source code**)
#
# *Please compress all the files into a single zipped file.*
#
#
# ** How to submit: **
#
#         Send an email to rcpaffenroth@wpi.edu and wliu3@wpi.edu with the subject: "[DS501] Case study 4-TEAM NUMBER ???".
