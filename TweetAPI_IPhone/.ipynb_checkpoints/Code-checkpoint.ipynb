# %% [markdown]
# # Case Study 1 : Collecting Data from Twitter
#
# Due Date: September 22, **before the beginning of class at 6:00pm**
#
# * ------------

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/en/thumb/9/9f/Twitter_bird_logo_2012.svg/220px-Twitter_bird_logo_2012.svg.png">

# %% [markdown]
# **TEAM Members:** Please EDIT this cell and add the names of all the team members in your team
#
#     Jiexuan Sun
#     Chao Xu
#     Congyang Wang
#     Zhaoning Su

# %% [markdown]
# **Required Readings:**
# * Chapter 1 and Chapter 9 of the book [Mining the Social Web](http://www.learndatasci.com/wp-content/uploads/2015/08/Mining-the-Social-Web-2nd-Edition.pdf)
# * The codes for [Chapter 1](http://bit.ly/1qCtMrr) and [Chapter 9](http://bit.ly/1u7eP33)
#
#
# ** NOTE **
# * Please don't forget to save the notebook frequently when working in IPython Notebook, otherwise the changes you made can be lost.
#
# *----------------------

# %% [markdown]
# # Problem 1: Sampling Twitter Data with Streaming API about a certain topic

# %% [markdown]
# * Select a topic that you are interested in, for example, "WPI" or "Lady Gaga"
# * Use Twitter Streaming API to sample a collection of tweets about this topic in real time. (It would be recommended that the number of tweets should be larger than 200, but smaller than 1 million.
# * Store the tweets you downloaded into a local file (txt file or json file)

# %%
import twitter
import json
#---------------------------------------------
# Define a Function to Login Twitter API
def oauth_login_stream():
    # Go to http://twitter.com/apps/new to create an app and get values
    # for these credentials that you'll need to provide in place of these
    # empty string values that are defined as placeholders.
    # See https://dev.twitter.com/docs/auth/oauth for more information 
    # on Twitter's OAuth implementation.
    
    CONSUMER_KEY = ''
    CONSUMER_SECRET =''
    OAUTH_TOKEN = ''
    OAUTH_TOKEN_SECRET = ''
    
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    
    twitter_stream = twitter.TwitterStream(auth=auth)
    
    print(twitter_stream)
    return twitter_stream


twitter_stream = oauth_login_stream()
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

iterator = twitter_stream.statuses.filter(track="iphone7", language="en")

#Collect 1000 tweets and save into a list. 
tweet_count = 1000
list=[]
for tweet in iterator:
    tweet_count -= 1
    list.append(tweet)
    
    if tweet_count <= 0:
        break 

data=json.dumps(list,indent=4)

#save the list into iphone_data.txt file.
file = open('iphone_data.txt','w')
file.write(data)
file.close()

# %% [markdown]
# ### Report some statistics about the tweets you collected
#
# * The topic of interest: iphone7
#
#
# * The total number of tweets collected: 1000

# %% [markdown]
# *-----------------------

# %% [markdown]
# # Problem 2: Analyzing Tweets and Tweet Entities with Frequency Analysis
#
# **1. Word Count:**
# * Use the tweets you collected in Problem 1, and compute the frequencies of the words being used in these tweets.
# * Plot a table of the top 30 words with their counts

# %%
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary
# Import the necessary package to process data in JSON format

from collections import Counter
from prettytable import PrettyTable
import json

#Open the iphone_data.txt and save the useful data into three lists.
tweets_filename = 'iphone_data.txt'
tweets_file = open(tweets_filename, "r")
data = tweets_file.read()
iphone_data = json.loads(data)

#list of tweets' text.
ip_texts = [ da['text'] for da in iphone_data]

#list of tweets' hashtags
hashtags = [ hashtag['text'] 
             for da in iphone_data
                 for hashtag in da['entities']['hashtags'] ]

#list of tweets' words.
words = [ w 
          for t in ip_texts 
              for w in t.split() ]


#Compute the frequencies of the words and plot a table of the top 30 words with their counts. 
label='Word'
pt = PrettyTable(field_names=[label, 'Count']) 
c = Counter(words)
print(c)
[ pt.add_row(kv) for kv in c.most_common()[:30] ]
pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
 'if': 8, 'Ooredoo': 8, 'screen': 8, 'by': 8, 'good': 8, '@Blessmome:': 8, 'https://t.co/FUl12PwiKM': 8, 'want': 8, '250k.': 8, 'they': 8, '1year!..': 8, '1m': 8, "Sunggyu's": 8, '@wowkyu91:': 8, 'free': 8, 'ikorodu': 8, '#ios10': 8, 'https://t.co/o1QoGqs38M': 8, '#UK': 8, 'one': 8, '@IHS': 8, 'getting': 8, 'wise!....…': 8, 'Is': 7, 'ur': 7, 'more': 7, '@shaadimagic': 7, '#Leeds': 7, '#iPadPro': 7, '#winiphone7': 7, '#iOS10': 7, 'too': 7, '#Business!': 7, '@jdnetworks:': 7, '#Like': 7, '#ShaadiMagic': 7, 'launches': 7, 'much': 7, '|': 7, 'than': 7, '#iPhone': 7, 'queues': 7, '.': 7, '@StatistaCharts:': 7, 'check': 7, 'iphone7?': 7, '#Matte': 7, 'Will': 7, 'Check': 7, 'give': 7, 'as': 7, 'enter': 7, 'Case': 7, 'user': 7, '+': 7, '@luki_mankin:': 7, 'ONLY': 7, '#innovation': 7, 'All': 7, 'already': 7, '#iPhone7…': 7, 'chance': 6, '@avasmv:': 6, 'TODAY.': 6, '!': 6, 'An': 6, 'i': 6, 'Apps': 6, 'quantity.': 6, '#iphone6s': 6, 'COMPETITION': 6, 'abt': 6, 'Ground': 6, 'got': 6, '#SME': 6, '#iOS10,': 6, "it's": 6, 'https://t.co/w415l11MEO': 6, 'who': 6, 'Chinese': 6, 'Iphone': 6, 'follow': 6, 'https://t.co/DR21mK45LJ': 6, 'My': 6, "It's": 6, '#iPhone7,': 6, 'breaks': 6, 'LimitedEdition': 6, '32GB': 6, 'TIME!': 6, 'next': 6, 'Our': 6, '@EE': 6, 'https://t.co/0lBHbKtQby': 6, '"@olisaosega': 6, 'had': 6, '#iphone6': 6, '@TheKaseUSA:': 6, 'https://t.co/1PnqDgiTL8': 6, '@tossin_o': 6, 'queue': 6, '#Retweet': 6, 'wireless': 6, 'link': 5, 'ready': 5, 'TO': 5, '🖕🏽': ...
# +--------------+-------+
# | Word         | Count |
# +--------------+-------+
# | #iPhone7     |   570 |
# | the          |   507 |
# | I            |   398 |
# | giveaway!    |   336 |
# | in           |   334 |
# | have         |   319 |
# | RT           |   301 |
# | participated |   283 |
# | to           |   172 |
# | for          |   113 |
# | is           |    96 |
# | and          |    95 |
# | a            |    94 |
# | 7            |    93 |
# | iphone7      |    92 |
# | &amp;        |    90 |
# | iPhone       |    80 |
# | #iphone7     |    78 |
# | of           |    78 |
# | iPhone7      |    73 |
# | just         |    64 |
# | -            |    62 |
# | get          |    61 |
# | new          |    58 |
# | entered      |    53 |
# | @UpsieHQ     |    53 |
# | @nbt88yt     |    53 |
# | @Eztech231   |    53 |
# | your         |    49 |
# | #iPhone7Plus |    49 |
# +--------------+-------+

# %% [markdown]
# **2. Find the most popular tweets in your collection of tweets**
#
# Please plot a table of the top 10 tweets that are the most popular among your collection, i.e., the tweets with the largest number of retweet counts.

# %%
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

#Save the retweets' informations into a list.
retweets = [
            # Store out a tuple of these three values ...
            (da['retweeted_status']['retweet_count'], 
             da['retweeted_status']['user']['screen_name'],
             da['text']) 
            # ... for each status ...
            for da in iphone_data 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in da
           ]

#Plot a table of the top 10 tweets with the largest number of retweet counts.
pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:10] ]
pt.max_width['Text'] = 60
pt.align= 'l'
print(pt)
# Out:
# +-------+-------------+--------------------------------------------------------------+
# | Count | Screen Name | Text                                                         |
# +-------+-------------+--------------------------------------------------------------+
# | 2033  | YOONAYAcom  | RT @YOONAYAcom: 【YOONAYA gift】160920  128G iPhone7 Plus for |
# |       |             | YoonA https://t.co/sRSft2jWAw                                |
# | 1434  | ChiefKeef   | RT @ChiefKeef: Flexing on Hoe ass niggas With this new       |
# |       |             | iphone7 shit 😂😇😠 https://t.co/6tefmN8Qoq                     |
# | 1433  | ChiefKeef   | RT @ChiefKeef: Flexing on Hoe ass niggas With this new       |
# |       |             | iphone7 shit 😂😇😠 https://t.co/6tefmN8Qoq                     |
# | 1412  | luki_mankin | RT @luki_mankin: Get your FREE #iPhone7 #iPhone7Plus ONLY    |
# |       |             | TODAY.  LimitedEdition and limited quantity.                 |
# |       |             | https://t.co/w415l11MEO https://t.c…                         |
# | 1411  | luki_mankin | RT @luki_mankin: Get your FREE #iPhone7 #iPhone7Plus ONLY    |
# |       |             | TODAY.  LimitedEdition and limited quantity.                 |
# |       |             | https://t.co/w415l11MEO https://t.c…                         |
# | 1410  | luki_mankin | RT @luki_mankin: Get your FREE #iPhone7 #iPhone7Plus ONLY    |
# |       |             | TODAY.  LimitedEdition and limited quantity.                 |
# |       |             | https://t.co/w415l11MEO https://t.c…                         |
# | 1409  | luki_mankin | RT @luki_mankin: Get your FREE #iPhone7 #iPhone7Plus ONLY    |
# |       |             | TODAY.  LimitedEdition and limited quantity.                 |
# |       |             | https://t.co/w415l11MEO https://t.c…                         |
# | 1408  | luki_mankin | RT @luki_mankin: Get your FREE #iPhone7 #iPhone7Plus ONLY    |
# |       |             | TODAY.  LimitedEdition and limited quantity.                 |
# |       |             | https://t.co/w415l11MEO https://t.c…                         |
# | 1407  | luki_mankin | RT @luki_mankin: Get your FREE #iPhone7 #iPhone7Plus ONLY    |
# |       |             | TODAY.  LimitedEdition and limited quantity.                 |
# |       |             | https://t.co/w415l11MEO https://t.c…                         |
# | 1110  | KeeganAllen | RT @KeeganAllen: iPhone7 had room for Jack. Smh              |
# |       |             | https://t.co/5Vmzh6WrCl                                      |
# +-------+-------------+--------------------------------------------------------------+

# %% [markdown]
# **3. Find the most popular Tweet Entities in your collection of tweets**
#
# Please plot a table of the top 10 hashtags, top 10 user mentions that are the most popular in your collection of tweets.

# %%
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

#Save the hashtags' information into a list.
hashtags = [ hashtag['text'] 
             for da in iphone_data
                 for hashtag in da['entities']['hashtags'] ]

#Save the usermentions' information into a list.
usermentions = [ mention['name']
                 for da in iphone_data
                    for mention in da['entities']['user_mentions'] ]

#Plot a table of the top 10 hashtags and top 10 user mentions.
for label, data in(('hashtags',hashtags),
                   ('user mentions',usermentions)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +-------------+-------+
# | hashtags    | Count |
# +-------------+-------+
# | iPhone7     |   594 |
# | iphone7     |    80 |
# | iPhone7Plus |    49 |
# | Apple       |    36 |
# | UAE         |    25 |
# | idcitforum  |    25 |
# | Dubai       |    25 |
# | IDCITFORUM  |    23 |
# | iphone      |    18 |
# | Win         |    17 |
# +-------------+-------+
# +---------------------+-------+
# | user mentions       | Count |
# +---------------------+-------+
# | NothingButTech88    |    53 |
# | Zachary Anderson    |    53 |
# | Upsie               |    53 |
# | Hazem  حازم إسماعيل |    46 |
# | Shaadi Magic        |    21 |
# | Apple               |    19 |
# | HONY PH.D TROUBLEM  |    14 |
# | T-bag               |    14 |
# | Your future husband |    13 |
# | Austin Creed        |    12 |
# +---------------------+-------+

# %% [markdown]
# * ------------------------
#
# # Problem 3: Getting "All" friends and "All" followers of a popular user in twitter

# %% [markdown]
# * choose a popular twitter user who has many followers, such as "ladygaga".
# * Get the list of all friends and all followers of the twitter user.
# * Plot 20 out of the followers, plot their ID numbers and screen names in a table.
# * Plot 20 out of the friends (if the user has more than 20 friends), plot their ID numbers and screen names in a table.

# %%
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary
import tweepy
from tweepy import Stream, OAuthHandler
from tweepy.streaming import StreamListener
from prettytable import PrettyTable

#Variables that contains the user credentials to access Twitter API. 
CONSUMER_KEY = 'TJbcvtJKeOLIC7VJ1P1ueD0Ex'
CONSUMER_SECRET ='Bt30IV0EXK4TOIkuonXEA8llQPW8IsFc8Hhh9y5lSGrWUjtRZv'
ACCESS_TOKEN = '776632770185596928-HleyQ6UtvVPWVcd19vdE8lMz48A3VoJ'
ACCESS_SECRET = 'ph1fjEuyT7ED7zNPoUTL3ZEJGqxRhJBRtAqEH5z7CZXHp'
    
#Connect the API.
auth = OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
api = tweepy.API(auth) 

#Provides a wrapper for the API as provided by Twitter.
      
if __name__ == "__main__":
    user_choose = "Tim_Cook"
    user = api.get_user(user_choose) #Returns information about the specified user.
    print(user.screen_name)
  
    #The applying of functions is refer to http://tweepy.readthedocs.io/en/v2.3.0/api.html#user-methods   
    friends = api.friends_ids(user_choose) 
    followers = api.followers_ids(user_choose)
    
    #!!!The tweet Api limit us to get up to 5000 user's friends/followers!!! 
    #!!!So, even though Tim Cook have approximately 3450000 followers, we could only get a 5000 follower's id!!!
    #!!!Check http://docs.tweepy.org/en/v3.5.0/api.html for details!!!
    
    print('Number of friends:')
    print(len(friends))
    print("Number of followers(The tweet Api limit us to get up to 5000 user's friends/followers):")
    print(len(followers))
    
    #Get the first 20 id of friends/followers
    friend_list = friends[0:20]    
    follower_list = followers[0:20]
  
    #Plot 20 out of the friends
    user_choose_friends = PrettyTable(["user_id","screen_name"])
    for friends_id in (friend_list)[0:20]:
        user_choose_friends.add_row([friends_id, api.get_user(friends_id).screen_name] )
    print("user_choose_friends")
    print(user_choose_friends)
  
    #Plot 20 out of the followers
    user_choose_follows = PrettyTable(["user_id","screen_name"])
    for follows_id in (follower_list)[0:20]:
        user_choose_follows.add_row([follows_id, api.get_user(follows_id).screen_name] )
    print("user_choose_follows")
    print(user_choose_follows)
# Out:
# tim_cook
# Number of friends
# 51
# Number of followers(The tweet Api limit us to get up to 5000 user's friends/followers)
# 5000
# user_choose_friends
# +------------+---------------+
# |  user_id   |  screen_name  |
# +------------+---------------+
# |  90420314  |  ActuallyNPH  |
# |  29450962  |  repjohnlewis |
# |     12     |      jack     |
# |  14130366  |  sundarpichai |
# | 3257608936 |   AppleNews   |
# | 3309375033 |  AppleSupport |
# | 1205322793 |    mspear96   |
# |  21872269  | laurenepowell |
# |  16303106  | StephenAtHome |
# |  21288052  |    zanelowe   |
# |    1605    |      sama     |
# | 1582853809 | HistoryInPics |
# | 2204034272 |     Beats1    |
# | 338084918  |    Pharrell   |
# | 1182675871 |  lisapjackson |
# |  19608297  |      HRC      |
# |  69231187  | UNHumanRights |
# |  20571756  |  satyanadella |
# |  21133007  |  OneRepublic  |
# |   914061   |     levie     |
# +------------+---------------+
# user_choose_follows
# +--------------------+-----------------+
# |      user_id       |   screen_name   |
# +--------------------+-----------------+
# | 779043546728759297 |    Vj_saxena    |
# |     1084351826     |     beckyskr    |
# |     503206587      |   orchidfrost   |
# | 779043100996100096 |  cupello_lenore |
# | 779043048160366593 |  kenyattakechi3 |
# |      21202107      |   Jake_Mathers  |
# |      35488827      |     AishaJ7     |
# | 779042100348203008 |    BGrant2016   |
# | 779041418106974208 |  Michellemsong  |
# | 779041528178245634 | BrandManaging16 |
# | 779040393551720449 |    MinulRobim   |
# | 735684333021724672 |    24HourBrew   |
# |     910839768      |    pritammshr   |
# | 779039735893397505 |  nexodoc_global |
# | 779041622424072192 |     ipn1433     |
# | 756769427610185728 |   SobhyAbrahim  |
# | 726636744645435392 | SivakumarSubra7 |
# |     4909826322     |  BiserRangelov  |
# | 766144766132322304 |   SaMRamo9424   |
# | 772033629723635712 |      bnuzll     |
# +--------------------+-----------------+

# %% [markdown]
# * Compute the mutual friends within the two groups, i.e., the users who are in both friend list and follower list, plot their ID numbers and screen names in a table

# %%
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

#Get the mutual friend's list.
api.get_user(friends_id).screen_name
mutual = set(friends).intersection(set(followers))
print("Mutual friend's set:")
print(mutual)

#Plot mutual friend's ID numbers and screen names in a table
mutual_friends = PrettyTable(["user_id","screen_name"])
for friends_id in mutual:
    mutual_friends.add_row([friends_id, api.get_user(friends_id).screen_name] )
    
    
print("mutual_friends")
print(mutual_friends)
# Out:
# Mutual friend's set:
# set()
# mutual_friends
# +---------+-------------+
# | user_id | screen_name |
# +---------+-------------+
# +---------+-------------+

# %% [markdown]
# *------------------------
#
# # Problem 4: Business question
#
# Run some additional experiments with your data to gain familiarity with the twitter data and twitter API.
#
# * Come up with a business question that Twitter data could help answer.
# * Decribe the business case.
# * How could Twitter data help a company decide how to spend its resources.

# %%
#----------------------------------------------
# Your code starts here
#   Please add comments or text cells in between to explain the general idea of each block of the code.
#   Please feel free to add more cells below this cell if necessary

#If we are sales department member of Apple Inc., we want to adivertise our the new IPhone product. We want to
#decide on which counties we should adivertise. So, we want to know which countries' people talking about 
#IPhone7 more often. And, We plot a table to show the tweet’s distribution based on different countries
#Then, we will adivertise on UK as the result shows!

import twitter
import json
inf = [ da['user']['location']
                 for da in iphone_data]
#print(inf)

pt = PrettyTable(field_names=['location', 'Count']) 
c = Counter(inf)
print(c)
[ pt.add_row(kv) for kv in c.most_common()[:30] ]
pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
eria ': 1, 'Barnala': 1, 'New Albany, IN': 1, '晴美台': 1, 'New York ': 1, 'Bengaluru, India': 1, 'BPT': 1, 'Riverrsidee .(: ': 1, 'Berlin (next to all the shops)': 1, 'Sea of the stars': 1, 'Born & Raised in LA✔': 1, 'Michigan, USA': 1, '穂むら': 1, 'BLACKPINK♥': 1, 'Tukwila Head ': 1, 'Hollywood, CA': 1, 'South Africa/Nigeria': 1, 'INDIA-HYDERABAD': 1, 'エログロお耽美娘': 1, 'Nagaland, India': 1, 'tx': 1, '#blacklivesmatter': 1, '#Bristol, England': 1, 'ojodu, Lagos State': 1, 'Ukraina': 1, '目指せ健康なデブ': 1, 'ny': 1, 'Asgard': 1, 'Stamford Bridge, England': 1, 'Brighton, England': 1, 'N.': 1, 'Manila City, National Capital ': 1, 'Barcelona, Spain': 1, 'Cologne, GERMANY': 1, 'Piedmont, Italy': 1, 'Long Beach, NY': 1, 'Lagos Nigeria': 1, 'München, Munich': 1, 'Krokrobite, Ghana': 1, 'USA | Europe': 1, 'No se donde estoy pero te veo': 1, 'shenzhen of china': 1, 'indonesia': 1, 'Loading...............': 1, 'Derby ': 1, 'land': 1, '♥': 1, 'Wrexham': 1, 'Punjab, Pakistan': 1, 'Land Of Bananas': 1, 'Fяєєвαи∂z, υѕα': 1, 'mnl philippines': 1, 'Egypt': 1, ' S N E A K E R H U B  ⛩': 1, 'South Carolina': 1, 'भारत ': 1, 'Location Kuala Lumpur Malaysia': 1, 'Johannesburg , South Africa': 1, 'Norway': 1, '28/5/16': 1, 'San Diego': 1, 'Cupertino, CA': 1, 'Meycauayan City': 1, 'United Kingdom/Okinawa,Japan': 1, 'Kingdom of Morocco ': 1, 'from another planet...': 1, 'Mahesana, India': 1, '( ͡° ͜ʖ ͡°)': 1, 'in the cs/colifer trash can': 1, 'San Mateo, CA': 1, 'LAGOS, NIGERIA': 1, 'Abuja, Lagos, Jos. ': 1, 'Jetzt im Kühlregal': 1, 'davao city': 1, '1248': 1, 'htx': 1, 'dedham': 1, 'Morón, Argentina': 1, 'South Africa ...
# +-----------------------------+-------+
# |           location          | Count |
# +-----------------------------+-------+
# |             None            |   312 |
# |              UK             |    26 |
# | Dubai, United Arab Emirates |    14 |
# |        New York, USA        |    12 |
# |            India            |    11 |
# |           Maldives          |     9 |
# |           Nigeria           |     8 |
# |        United States        |     8 |
# |            World            |     7 |
# |       London, England       |     7 |
# |             UAE             |     5 |
# |              US             |     5 |
# |        Lagos, Nigeria       |     5 |
# |       New Delhi, India      |     5 |
# |             USA             |     5 |
# |       California, USA       |     4 |
# |   England, United Kingdom   |     4 |
# |            Jordan           |     4 |
# |          London-UK          |     4 |
# |       Los Angeles, CA       |     4 |
# |            London           |     4 |
# |        Mumbai, India        |     4 |
# |       München, Bayern       |     4 |
# |          Singapore          |     3 |
# |          New Delhi          |     3 |
# |     United Arab Emirates    |     3 |
# |         west bengal         |     3 |
# |        International        |     3 |
# |        United States        |     3 |
# |        United Kingdom       |     3 |
# +-----------------------------+-------+

# %% [markdown]
# *-----------------
# # Done
#
# All set!
#
# ** What do you need to submit?**
#
# * **Notebook File**: Save this IPython notebook, and find the notebook file in your folder (for example, "filename.ipynb"). This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook. If you used "ipython notebook --pylab=inline" to open the notebook, all the figures and tables should have shown up in the notebook.
#
#
# * **PPT Slides**: please prepare PPT slides (for 10 minutes' talk) to present about the case study . We will ask two teams which are randomly selected to present their case studies in class for this case study.
#
# * ** Report**: please prepare a report (less than 10 pages) to report what you found in the data.
#     * What data you collected?
#     * Why this topic is interesting or important to you? (Motivations)
#     * How did you analyse the data?
#     * What did you find in the data?
#
#      (please include figures or tables in the report, but no source code)
#
# Please compress all the files in a zipped file.
#
#
# ** How to submit: **
#
#         Please submit through email to Prof. Paffenroth (rcpaffenroth@wpi.edu) *and* the TA Wen Liu (wliu3@wpi.edu).
#
# ** Note: Each team just needs to submits one submission **

# %% [markdown]
# # Grading Criteria:
#
# ** Totoal Points: 120 **
#
#
# ---------------------------------------------------------------------------
# ** Notebook:  **
#     Points: 80
#
#
#     -----------------------------------
#     Qestion 1:
#     Points: 20
#     -----------------------------------
#
#     (1) Select a topic that you are interested in.
#     Points: 6
#
#     (2) Use Twitter Streaming API to sample a collection of tweets about this topic in real time. (It would be recommended that the number of tweets should be larger than 200, but smaller than 1 million. Please check whether the total number of tweets collected is larger than 200?
#     Points: 10
#
#
#     (3) Store the tweets you downloaded into a local file (txt file or json file)
#     Points: 4
#
#
#     -----------------------------------
#     Qestion 2:
#     Points: 20
#     -----------------------------------
#
#     1. Word Count
#
#     (1) Use the tweets you collected in Problem 1, and compute the frequencies of the words being used in these tweets.
#     Points: 4
#
#     (2) Plot a table of the top 30 words with their counts
#     Points: 4
#
#     2. Find the most popular tweets in your collection of tweets
#     plot a table of the top 10 tweets that are the most popular among your collection, i.e., the tweets with the largest number of retweet counts.
#     Points: 4
#
#     3. Find the most popular Tweet Entities in your collection of tweets
#
#     (1) plot a table of the top 10 hashtags,
#     Points: 4
#
#     (2) top 10 user mentions that are the most popular in your collection of tweets.
#     Points: 4
#
#
#     -----------------------------------
#     Qestion 3:
#     Points: 20
#     -----------------------------------
#
#     (1) choose a popular twitter user who has many followers, such as "ladygaga".
#     Points: 4
#
#     (2) Get the list of all friends and all followers of the twitter user.
#     Points: 4
#
#     (3) Plot 20 out of the followers, plot their ID numbers and screen names in a table.
#     Points: 4
#
#     (4) Plot 20 out of the friends (if the user has more than 20 friends), plot their ID numbers and screen names in a table.
#     Points: 4
#
#     (5) Compute the mutual friends within the two groups, i.e., the users who are in both friend list and follower list, plot their ID numbers and screen names in a table
#     Points: 4
#
#     -----------------------------------
#     Qestion 4:  Business question
#     Points: 20
#     -----------------------------------
#         Novelty: 10
#         Interestingness: 10
#     -----------------------------------
#     Run some additional experiments with your data to gain familiarity with the twitter data ant twitter API.  Come up with a business question and describe how Twitter data can help you answer that question.
#
#
#
#
# ---------------------------------------------------------------------------
# ** Report: communicate the results**
#     Points: 20
#
# (1) What data you collected?
#     Points: 5
#
# (2) Why this topic is interesting or important to you? (Motivations)
#     Points: 5
#
# (3) How did you analyse the data?
#     Points: 5
#
# (4) What did you find in the data?
# (please include figures or tables in the report, but no source code)
#     Points: 5
#
#
#
# ---------------------------------------------------------------------------
# ** Slides (for 10 minutes of presentation): Story-telling **
#     Points: 20
#
#
# 1. Motivation about the data collection, why the topic is interesting to you.
#     Points: 5
#
# 2. Communicating Results (figure/table)
#     Points: 10
#
# 3. Story telling (How all the parts (data, analysis, result) fit together as a story?)
#     Points: 5
